# %%
# pip install -U qwen-asr
# Imports
import librosa
import torch
import jiwer
import pandas as pd
from whisper.normalizers.basic import BasicTextNormalizer
from tqdm.notebook import tqdm
from qwen_asr import Qwen3ASRModel

# Dispositivo = GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Ejecutando en: {device}")
# Out:
# Ejecutando en: cuda:0

# %%
# Cargar modelo
repo_id = "Qwen/Qwen3-ASR-1.7B"
print(f"Cargando modelo: {repo_id}")

model = Qwen3ASRModel.from_pretrained(
    repo_id,
    dtype=torch.bfloat16,
    device_map="cuda:0",
    max_new_tokens=4096,
)
# Out:
# Cargando modelo: Qwen/Qwen3-ASR-1.7B
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.

# %%
audios = []

lst_path = r"..\..\Europarl-ST\en\es\test\Europarl-ST.v2.en.es.test.lst"

with open(lst_path, "r", encoding="utf-8") as lista_audios:
    for linea in lista_audios:
        if linea.strip():
            audios.append(str(linea).strip())
        
print(f"Total de audios a procesar: {len(audios)}")
# Out:
# Total de audios a procesar: 127

# %%
hypotheses = []
references = []

for audio in tqdm(audios, desc="Transcribiendo con Qwen3-ASR (inglés)"):
    
    ref_path = r"..\..\Europarl-ST\en\es\test\%s\transcription.tok" % audio
    with open(ref_path, "r", encoding="utf-8") as referencia:
        references.append(referencia.read())

    audio_path = r"..\..\Europarl-ST\en\es\test\%s\audio_clip_diarization.m4a" % audio
    audio_array, sr = librosa.load(audio_path, sr=16000)
    
    results = model.transcribe(audio=(audio_array, sr), language="English")
    
    hypotheses.append(results[0].text)
# Out:
# Transcribiendo con Qwen3-ASR (inglés):   0%|          | 0/127 [00:00<?, ?it/s]
# C:\Users\carru\AppData\Local\Temp\ipykernel_16320\615052592.py:11: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio_array, sr = librosa.load(audio_path, sr=16000)
# d:\carru\voxtral-tfg\venv_qwen\Lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# C:\Users\carru\AppData\Local\Temp\ipykernel_16320\615052592.py:11: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio_array, sr = librosa.load(audio_path, sr=16000)
# d:\carru\voxtral-tfg\venv_qwen\Lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.

# %%
# Crear DataFrame y guardar resultados
data = pd.DataFrame(dict(hypothesis=hypotheses, reference=references))

data.to_csv("qwen_raw_results_en.csv", index=False)

data.head()
# Out:
#                                           hypothesis  \
# 0  It is only greed, euphoria, and cheap money to...
# 1  The financial crisis rages on, and European eu...
# 2  This crisis has demonstrated that the global f...
# 3  Thank you. There are going to be radical chang...
# 4  Madam President, sometimes a question flies aw...
#
#                                            reference
# 0  Madam President , are only greed , euphoria an...
# 1  Madam President , the financial crisis rages o...
# 2  Mr President , this crisis has demonstrated th...
# 3  Mr President , there are going to be radical c...
# 4  Sometimes a question flies away , and this is ...

# %%
# Normalización de texto para evaluación
normalizer = BasicTextNormalizer()

data["hypothesis_clean"] = [normalizer(str(text)) for text in data["hypothesis"]]
data["reference_clean"] = [normalizer(str(text)) for text in data["reference"]]

data.to_csv("qwen_resultados_limpios_en.csv", index=False)

data.head()
# Out:
#                                           hypothesis  \
# 0  It is only greed, euphoria, and cheap money to...
# 1  The financial crisis rages on, and European eu...
# 2  This crisis has demonstrated that the global f...
# 3  Thank you. There are going to be radical chang...
# 4  Madam President, sometimes a question flies aw...
#
#                                            reference  \
# 0  Madam President , are only greed , euphoria an...
# 1  Madam President , the financial crisis rages o...
# 2  Mr President , this crisis has demonstrated th...
# 3  Mr President , there are going to be radical c...
# 4  Sometimes a question flies away , and this is ...
#
#                                     hypothesis_clean  \
# 0  it is only greed euphoria and cheap money to b...
# 1  the financial crisis rages on and european eur...
# 2  this crisis has demonstrated that the global f...
# 3  thank you there are going to be radical change...
# 4  madam president sometimes a question flies awa...
#
#                                      reference_clean
# 0  madam president are only greed euphoria and ch...
# 1  madam president the financial crisis rages on ...
# 2  mr president this crisis has demonstrated that...
# 3  mr president there are going to be radical cha...
# 4  sometimes a question flies away and this is pe...

# %%
# Cálculo del Word Error Rate (WER)
wer = jiwer.wer(list(data["reference_clean"]), list(data["hypothesis_clean"]))

print(f"WER final de Qwen3-ASR: {wer * 100:.2f} %")
# Out:
# WER final de Qwen3-ASR: 11.50 %

# %% [markdown]
# *(Completar tras la ejecución: WER obtenido en inglés.)*
